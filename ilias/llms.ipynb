# %% [markdown]
# # Use LLMs to handle headlines

# %% [markdown]
# ### Import the data

# %%
import pandas as pd

# Read the seen and unseen data
train_seen = pd.read_parquet("../data/bars_seen_train.parquet")
train_unseen = pd.read_parquet("../data/bars_unseen_train.parquet")

headlines_seen = pd.read_parquet("../data/headlines_seen_train.parquet")
headlines_unseen = pd.read_parquet("../data/headlines_unseen_train.parquet")

# %% [markdown]
# ### Call the LLM

# %%
SESSION_ID = 600

headlines_seen[headlines_seen["session"] == SESSION_ID][["headline", "bar_ix"]]

# Convert filtered dataframe to string
subset = headlines_seen[headlines_seen["session"] == SESSION_ID][["headline", "bar_ix"]]
prompt_string = subset.to_string(index=False)

# Or better yet, format it as a list for the prompt:
formatted_list = "\n".join([f"Day {row.bar_ix}: {row.headline}" for _, row in subset.iterrows()])
formatted_list
# Out:
# 'Day 0: Calvos Genomics wins industry award for excellence in automated logistics\nDay 1: Zrovum Biopharma announces breakthrough in digital payments\nDay 5: Zelvix Therapeutics secures $650M contract with a top-tier research institute\nDay 13: Zrovum Biopharma secures $400M contract with a top-tier research institute\nDay 26: Zelvix Therapeutics completes strategic acquisition to strengthen enterprise software\nDay 29: Nerval Biopharma explores strategic alternatives for supply chain optimization unit\nDay 32: Zrovum Biopharma secures $75M contract with a major logistics provider\nDay 40: Calvos Genomics announces significant capital expenditure plan for Scandinavia\nDay 47: Nerval Biopharma faces class action over precision manufacturing service disruption'

# %%
import pandas as pd

# Load and access the last 'close' price for seen data
train_seen[train_seen["session"] == SESSION_ID]
train_seen = pd.read_parquet("../data/bars_seen_train.parquet")
mid_cost = train_seen["close"].iloc[-1]

# Load and access the last 'close' price for unseen data
train_unseen[train_unseen["session"] == SESSION_ID]
train_unseen = pd.read_parquet("../data/bars_unseen_train.parquet")
final_cost = train_unseen["close"].iloc[-1]
print(final_cost - mid_cost)
# Out:
# 0.018199999999999994

# %%
import anthropic
from dotenv import load_dotenv

load_dotenv()

client = anthropic.Anthropic()  # automatically reads ANTHROPIC_API_KEY

message = client.messages.create(
    model="claude-sonnet-4-6",
    max_tokens=1024,
    messages=[
        {"role": "user", "content": 
         "Explain recursion in simple terms."}
    ]
)

print(message.content[0].text)
# Out:
# # Recursion Explained Simply
#
# ## The Core Idea
# **A function that calls itself to solve a smaller version of the same problem.**
#
# ---
#
# ## A Simple Analogy
#
# Imagine you're standing in a line and want to know what position you're in.
#
# - You ask the person in front of you their position
# - *They* ask the person in front of *them*
# - This keeps going until the person at the **front** says "I'm #1"
# - Then everyone counts back: "I'm #2", "I'm #3"... until you get your answer
#
# ---
#
# ## A Code Example
#
# ```python
# def countdown(n):
#     if n == 0:          # BASE CASE - stop here
#         print("Done!")
#     else:
#         print(n)
#         countdown(n - 1)  # calls itself with a smaller value
#
# countdown(3)
# # Output: 3, 2, 1, Done!
# ```
#
# ---
#
# ## Two Required Parts
#
# | Part | Purpose | What happens without it |
# |------|---------|------------------------|
# | **Base case** | Tells it when to stop | Infinite loop → crash |
# | **Recursive case** | Breaks problem into smaller piece | Never makes progress |
#
# ---
#
# ## The Simple Mental Model
#
# > *"Assume the function already works for smaller inputs — just use it."*
#
# Each call handles **one piece**, then hands off the rest.
#
# ---
#
# ## When Is It Useful?
# - Tree/folder structures
# - Mathematical sequences (factorial, Fibonacci)
# - Anything that has a **naturally nested structure**
#
# Want a deeper example?
